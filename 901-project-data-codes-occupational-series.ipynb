# %%
import requests   # Import requests library
import pandas as pd

# %%
pd.set_option('display.max_rows',700)
pd.set_option('display.max_colwidth',400)

# %%
from pandas import json_normalize

# %%
usa_job_codes = requests.get('https://data.usajobs.gov/api/codelist/occupationalseries')

# %%
print(usa_job_codes.status_code)   # status code
# Out:
# 200

# %%
type(usa_job_codes)
# Out:
# requests.models.Response

# %%
code_results = usa_job_codes.json()

# %%
type(code_results)
# Out:
# dict

# %%
code_results['CodeList'][0].keys()
# Out:
# dict_keys(['ValidValue', 'id'])

# %%
code_results['CodeList'][0]['ValidValue']
# Out:
# [{'Code': '0001',
#   'Value': 'Special-10 Point Veteran',
#   'LastModified': '2021-11-29T10:43:31.883',
#   'IsDisabled': 'Yes',
#   'JobFamily': '0000'},
#  {'Code': '0002',
#   'Value': 'Special Master',
#   'LastModified': '2021-11-29T10:43:31.887',
#   'IsDisabled': 'Yes',
#   'JobFamily': '0000'},
#  {'Code': '0006',
#   'Value': 'Correctional Institution Administration',
#   'LastModified': '2011-07-06T21:35:26.23',
#   'IsDisabled': 'No',
#   'JobFamily': '0000'},
#  {'Code': '0007',
#   'Value': 'Correctional Officer',
#   'LastModified': '2011-07-06T21:35:26.23',
#   'IsDisabled': 'No',
#   'JobFamily': '0000'},
#  {'Code': '0011',
#   'Value': 'Bond Sales Promotion',
#   'LastModified': '2011-07-06T21:35:26.23',
#   'IsDisabled': 'No',
#   'JobFamily': '0000'},
#  {'Code': '0017',
#   'Value': 'Explosives Safety Series',
#   'LastModified': '2011-11-10T08:29:00',
#   'IsDisabled': 'No',
#   'JobFamily': '0000'},
#  {'Code': '0018',
# ...

# %%
codes_df = json_normalize(code_results['CodeList'][0]['ValidValue'])

# %%
codes_df
# Out:
#      Code                                    Value             LastModified  \
# 0    0001                 Special-10 Point Veteran  2021-11-29T10:43:31.883
# 1    0002                           Special Master  2021-11-29T10:43:31.887
# 2    0006  Correctional Institution Administration   2011-07-06T21:35:26.23
# 3    0007                     Correctional Officer   2011-07-06T21:35:26.23
# 4    0011                     Bond Sales Promotion   2011-07-06T21:35:26.23
# ..    ...                                      ...                      ...
# 817  9995       Chief Radio Electronics Technician   2011-07-06T21:35:26.23
# 818  9996                 Medical Services Officer   2011-07-06T21:35:26.23
# 819  9997       First Radio Electronics Technician   2011-07-06T21:35:26.23
# 820  9998                       Yeoman-Storekeeper   2011-07-06T21:35:26.23
# 821  9999      Second Radio Electronics Technician   2011-07-06T21:35:26.23
#
#     IsDisabled JobFamily
# 0          Yes      0000
# ...

# %%
codes_df[codes_df['Code']=='2210']
# Out:
#      Code                              Value             LastModified  \
# 445  2210  Information Technology Management  2016-10-21T06:13:47.827
#
#     IsDisabled JobFamily
# 445         No      2200

# %%
codes_df['Value'].isna().sum()
# Out:
# 0

# %%
codes_df['Value'].value_counts(dropna=False)
# Out:
# Electrician                            2
# Special-10 Point Veteran               1
# Fuel Distribution System Mechanic      1
# Miscellaneous Lens And Crystal Work    1
# Optical Element Working                1
#                                       ..
# Photography                            1
# Audiovisual Production                 1
# Writing And Editing                    1
# Technical Writing And Editing          1
# Second Radio Electronics Technician    1
# Name: Value, Length: 821, dtype: int64

# %%
len(codes_df['Value'].value_counts(dropna=False))
# Out:
# 821

# %%
codes_df.iloc[538:]
# Out:
#      Code  \
# 538  3872
# 539  3901
# 540  3910
# 541  3940
# 542  4001
# 543  4005
# 544  4010
# 545  4101
# 546  4102
# 547  4104
# 548  4201
# 549  4204
# 550  4206
# 551  4255
# 552  4301
# 553  4352
# 554  4360
# 555  4361
# 556  4373
# 557  4401
# 558  4402
# 559  4403
# 560  4406
# 561  4413
# 562  4414
# 563  4416
# 564  4417
# 565  4419
# 566  4425
# 567  4440
# 568  4441
# 569  4446
# 570  4449
# 571  4450
# 572  4454
# 573  4601
# 574  4602
# 575  4604
# 576  4605
# 577  4607
# 578  4616
# 579  4639
# 580  4654
# 581  4701
# 582  4714
# 583  4715
# 584  4716
# 585  4717
# 586  4737
# 587  4741
# 588  4742
# 589  4745
# 590  4749
# 591  4754
# 592  4801
# 593  4804
# 594  4805
# 595  4806
# 596  4807
# 597  4808
# 598  4816
# 599  4818
# 600  4819
# 601  4820
# 602  4840
# 603  4848
# 604  4850
# 605  4855
# 606  5001
# 607  5002
# 608  5003
# 609  5026
# 610  5031
# 611  5034
# 612  5035
# 613  5042
# 614  5048
# 615  5201
# 616  5205
# 617  5210
# 618  5220
# 619  5221
# ...

# %%
job_codes = codes_df[['Code','Value']]

# %%
type(job_codes['Code'][0])
# Out:
# str

# %%
jobs_ser = [6, 7, 11, 17, 18, 19, 20, 21, 23, 25, 28, 29, 30, 50, 60, 62, 72, 80, 81, 82, 83, 84, 85, 86, 89, 90, 95,
            99, 101, 102, 105, 106, 107, 110, 119, 130, 131, 132, 134, 135, 136, 140, 142, 150, 160, 170, 180, 181,
            182, 183, 184, 185, 186, 187, 188, 189, 190, 193, 199, 201, 203, 241, 243, 244, 260, 299, 301, 302, 303,
            304, 305, 306, 308, 309, 313, 318, 319, 322, 326, 332, 334, 335, 340, 341, 342, 343, 344, 346, 347, 350,
            356, 357, 360, 361, 382, 390, 391, 392, 394, 399, 401, 403, 404, 405, 408, 410, 413, 414, 415, 421, 430,
            434, 435, 437, 440, 454, 455, 456, 457, 458, 459, 460, 462, 470, 471, 480, 482, 485, 486, 487, 499, 501,
            503, 505, 510, 511, 512, 525, 526, 530, 540, 544, 545, 560, 561, 570, 580, 592, 593, 599, 601, 602, 603,
            605, 610, 620, 621, 622, 625, 630, 631, 633, 635, 636, 638, 640, 642, 644, 645, 646, 647, 648, 649, 650,
            5313, 5317, 5318, 5323, 5334, 5350, 5352, 5378, 5401, 5402, 5406, 5407, 5408, 5409, 5413, 5415, 5419, 5423,
            5426, 5427, 5438, 5439, 5440, 5701, 5703, 5704, 5705, 5716, 5725, 5729, 5736, 5737, 5738, 5767, 5782, 5784,
            5786, 5788, 5801, 5803, 5806, 5823, 5876, 6501, 6502, 6505, 6511, 6517, 6601, 6605, 6610, 6641, 6652, 6656,
            6901, 6904, 6907, 6910, 6912, 6913, 6914, 6941, 6968, 7001, 7002, 7006, 7009, 7301, 7304, 7305, 7401, 7402,
            7404, 7405, 7407, 7408, 7420, 7601, 7603, 8201, 8255, 8268, 8601, 8602, 8610, 8801, 8810, 8840, 8852, 8862,
            9902, 9904, 9905, 9930, 9931, 9934, 9944, 9962, 9995, 9996, 9998, 9999]

# %%
type(jobs_ser[0])
# Out:
# int

# %%
len(jobs_ser)
# Out:
# 661

# %%
jobs_str = []

# %%
for x in jobs_ser:
    jobs_str.append(str(x))

# %%
len(jobs_str)
# Out:
# 661

# %%
type(jobs_str[0])
# Out:
# str

# %%
code_ser = list(job_codes['Code'])

# %%
type(code_ser[0])
# Out:
# str

# %%
len(code_ser)
# Out:
# 822

# %%
jobs = [
    
    '0006', '0007', '0011', '0017', '0018', '0019', '0020', '0021', '0023', '0025', '0028', '0029', '0030', '0050',
    '0060', '0062', '0072', '0080', '0081', '0082', '0083', '0084', '0085', '0086', '0089', '0090', '0095', '0099',
    '0101', '0102', '0105', '0106', '0107', '0110', '0119', '0130', '0131', '0132', '0134', '0135', '0136', '0140',
    '0142', '0150', '0160', '0170', '0180', '0181', '0182', '0183', '0184', '0185', '0186', '0187', '0188', '0189',
    '0190', '0193', '0199', '0201', '0203', '0241', '0243', '0244', '0260', '0299', '0301', '0302', '0303', '0304',
    '0305', '0306', '0308', '0309', '0313', '0318', '0319', '0322', '0326', '0332', '0334', '0335', '0340', '0341',
    '0342', '0343', '0344', '0346', '0347', '0350', '0356', '0357', '0360', '0361', '0382', '0390', '0391', '0392',
    '0394', '0399', '0401', '0403', '0404', '0405', '0408', '0410', '0413', '0414', '0415', '0421', '0430', '0434',
    '0435', '0437', '0440', '0454', '0455', '0456', '0457', '0458', '0459', '0460', '0462', '0470', '0471', '0480',
    '0482', '0485', '0486', '0487', '0499', '0501', '0503', '0505', '0510', '0511', '0512', '0525', '0526', '0530',
    '0540', '0544', '0545', '0560', '0561', '0570', '0580', '0592', '0593', '0599', '0601', '0602', '0603', '0605',
    '0610', '0620', '0621', '0622', '0625', '0630', '0631', '0633', '0635', '0636', '0638', '0640', '0642', '0644',
    '0645', '0646', '0647', '0648', '0649', '0650', '0651', '0660', '0661', '0662', '0665', '0667', '0668', '0669',
    '0670', '0671', '0672', '0673', '0675', '0679', '0680', '0681', '0682', '0683', '0685', '0688', '0690', '0696',
    '4801', '4804', '4805', '4807', '4816', '4818', '4819', '4820', '4840', '4850', '4855', '5001', '5002', '5003',
    '5026', '5031', '5042', '5048', '5201', '5205', '5210', '5220', '5221', '5301', '5306', '5309', '5310', '5313', 
    '5317', '5318', '5323', '5334', '5350', '5352', '5378', '5401', '5402', '5406', '5407', '5408', '5409', '5413',
    '5415', '5419', '5423', '5426', '5427', '5438', '5439', '5440', '5701', '5703', '5704', '5705', '5716', '5725',
    '5729', '5736', '5737', '5738', '5767', '5782', '5784', '5786', '5788', '5801', '5803', '5806', '5823', '5876',
    '6501', '6502', '6505', '6511', '6517', '6601', '6605', '6610', '6641', '6652', '6656', '6901', '6904', '6907',
    '6910', '6912', '6913', '6914', '6941', '6968', '7001', '7002', '7006', '7009', '7301', '7304', '7305', '7401',
    '7402', '7404', '7405', '7407', '7408', '7420', '7601', '7603', '8201', '8255', '8268', '8601', '8602', '8610',
    '8801', '8810', '8840', '8852', '8862', '9902', '9904', '9905', '9930', '9931', '9934', '9944', '9962', '9995',
    '9996', '9998', '9999'

]

# %%
drop_code = []

# %%
for code in code_ser:
    if code not in jobs:
        drop_code.append(code)

# %%
len(drop_code)
# Out:
# 161

# %%
len(codes_df['Code'])
# Out:
# 822

# %%
drop_idx = list(codes_df[codes_df['Code'].isin(drop_code)].index)

# %%
first = codes_df['Code']

# %%
second = pd.DataFrame(
    
    codes_df['Value'].str.title().str.replace('-',' ').str.strip()
    .str.split('(',expand=True)[0].str.strip()
    .str.rsplit(' ',n=1,expand=True)
)

# %%
second
# Out:
#                             0               1
# 0            Special 10 Point         Veteran
# 1                     Special          Master
# 2    Correctional Institution  Administration
# 3                Correctional         Officer
# 4                  Bond Sales       Promotion
# ..                        ...             ...
# 817   Chief Radio Electronics      Technician
# 818          Medical Services         Officer
# 819   First Radio Electronics      Technician
# 820                    Yeoman     Storekeeper
# 821  Second Radio Electronics      Technician
#
# [822 rows x 2 columns]

# %%
len(second[1].value_counts(dropna=False))
# Out:
# 219

# %%
len(second[0].value_counts(dropna=False))
# Out:
# 706

# %%
job_codes = pd.merge(
    
    first,
    second,
    how="right",
    left_index=True,
    right_index=True,
    sort=False,
    copy=False,
    indicator=False,
    validate='one_to_one',
    
)

# %%
job_codes[0] = job_codes[0].str.replace('And','').str.strip()
job_codes[1] = job_codes[1].fillna('Work').str.strip()

# %%
job_codes.head(650)
# Out:
#      Code                                                            0  \
# 0    0001                                             Special 10 Point
# 1    0002                                                      Special
# 2    0006                                     Correctional Institution
# 3    0007                                                 Correctional
# 4    0011                                                   Bond Sales
# 5    0017                                            Explosives Safety
# 6    0018                                  Safety  Occupational Health
# 7    0019                                                       Safety
# 8    0020                                                    Community
# 9    0021                                           Community Planning
# 10   0023                                           Outdoor Recreation
# 11   0025                                                         Park
# ...

# %%
job_codes.to_csv('job_codes.csv', index=False)
